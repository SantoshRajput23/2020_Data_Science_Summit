# %% [markdown]
# ## Data Science Summit - Python Challenge : 8-Queens Puzzle
#
# Description
#
# The eight queens puzzle is the problem of placing eight chess queens on an 8×8 chessboard so that no two queens threaten each other; thus, a solution requires that no two queens share the same row, column, or diagonal. The eight queens puzzle is an example of the more general n queens problem of placing n non-attacking queens on an n×n chessboard. (Source : https://en.wikipedia.org/wiki/Eight_queens_puzzle )
#
# Challenge
#
# The challenge is to generate one right sequence through Genetic Programming. The sequence has to be 8 numbers between 0 to 7. Each number represents the positions the Queens can be placed. Each number refers to the row number in the specific column
#
# 0 3 4 5 6 1 2 4
#
# · 0 is the row number in the column 0 where the Queen can be placed
#
# · 3 is the row number in the column 1 where the Queen can be placed
#
# Author : Santosh Singh Rajput
#
# July 2020

# %%
import random
from numpy.random import choice
import pandas as pd
import threading 
import _thread
import sys

global correct_sequence,return_code
return_code="0"

def main():
    solution_list=[]
    global return_code,correct_sequence,gen_num
    
    ##### Genetic Algorithm variables  #####
    chess_size = 8
    mutationRate = 0.01
    totalPopulation = 150
    crossOver = 0.5
    generationCount = 1000
    ########################################
    
    # Calling the class method solve_nqueens_puzzle() and storing the return value in solution_list
    solution_list=NQueens_puzzle(chess_size).solve_nqueens_puzzle() 

    for i in range(len(solution_list)):
            thread_name=''.join(solution_list[i])
            thread_instance = threading.Thread(target=preprocessing, args=(chess_size,thread_name,mutationRate,totalPopulation,crossOver,generationCount,)) 
            thread_instance.start()
    print_str="\n"+" ######## "+ correct_sequence +" is one of the correct sequence of Queens. It is generated first in generation no :"+ gen_num +" ######## "
    print(print_str)
    


def inital_population(totalPopulation, chess_size, target, secure_random, alpha_list):
    populationData = []
    fitnessData = []
    for outloop in range(totalPopulation):
        randomData = []
        fitnessScore = 0
        for inloop in range(chess_size):
            selectedData = secure_random.choice(alpha_list)
            if (selectedData == target[inloop]):
                fitnessScore = fitnessScore + 1
            randomData.append(selectedData)
        populationData.append(randomData)
        fitnessData.append(fitnessScore)
    return (populationData, fitnessData)



def preprocessing(chess_size, thread_name, mutationRate, totalPopulation, crossOver, generationCount):
    global return_code, gen_num

    secure_random = random.SystemRandom()
    target = thread_name
    alpha_list = [chr(x) for x in range(ord('0'), ord('7') + 1)]
    populationData = []
    fitnessData = []
    populationData, fitnessData = inital_population(totalPopulation, chess_size, target, secure_random, alpha_list)
    probabilityDist = []
    for outloop in range(totalPopulation):
        probabilityDist.append(fitnessData[outloop] / len(target))
    probDataFrame = pd.DataFrame(
        {'String': populationData, 'FitnessScore': fitnessData, 'Probability': probabilityDist})
    probDataFrame = probDataFrame.sort_values(['Probability'], ascending=False)
    probDataFrame = probDataFrame.reset_index(drop=True)
    probDataFrame.head()
    crossover_n_mutation(alpha_list, crossOver, target, generationCount, probDataFrame, thread_name, secure_random,
                         populationData, probabilityDist, fitnessData)

        
        
def crossover_n_mutation(alpha_list, crossOver, target, generationCount, probDataFrame, thread_name, secure_random,
                         populationData, probabilityDist, fitnessData):
    global return_code, correct_sequence, gen_num

    crossOverPoint = int(crossOver * len(target))
    # print("\n")
    for loop in range(generationCount):
        if return_code == "1":
            sys.exit(0)
        else:
            draw = []
            draw.append(probDataFrame[0:1]["String"].values[0])
            draw.append(probDataFrame[1:2]["String"].values[0])
            if (getFitnessScore(draw[0], target) == len(target) | getFitnessScore(draw[1], target) == len(target)):
                print_str = ""
                print_str0 = ''.join([elem for elem in draw[0]])
                print_str1 = ''.join([elem for elem in draw[1]])
                print(print_str)

                return_code = "1"
                correct_sequence = thread_name

                gen_num = str(loop)
                sys.exit(0)
                break
            child1 = draw[0][0:crossOverPoint] + draw[1][crossOverPoint:]
            child2 = draw[1][0:crossOverPoint] + draw[0][crossOverPoint:]
            child1[random.randint(0, len(target) - 1)] = secure_random.choice(alpha_list)
            child2[random.randint(0, len(target) - 1)] = secure_random.choice(alpha_list)
            populationData.append(child1)
            populationData.append(child2)
            fitnessData = []
            totalPopulation = len(populationData)
            for outloop in range(totalPopulation):
                fitnessScore = getFitnessScore(populationData[outloop], target)
                fitnessData.append(fitnessScore)
            probabilityDist = []
            for outloop in range(totalPopulation):
                probabilityDist.append(fitnessData[outloop] / sum(fitnessData))
            probDataFrame = pd.DataFrame(
                {'String': populationData, 'FitnessScore': fitnessData, 'Probability': probabilityDist})
            probDataFrame = probDataFrame.sort_values(['Probability'], ascending=False)
            probDataFrame = probDataFrame.reset_index(drop=True)
            if return_code == "1":
                sys.exit(0)
            else:

                a = ""
                output_string = "\n" + 'Thread ' + str(thread_name) + ' Generation ' + str(
                    loop) + ' ' + '|Offspring1 :' + ''.join(elem for elem in child1) + '|FS of Offspring1: ' + str(
                    getFitnessScore(child1, target)) + '|Offspring2 :' + ''.join(
                    elem for elem in child2) + '|FS of Offspring2 :' + str(getFitnessScore(child2, target))
                print(output_string)

                
            
def getFitnessScore(data,target):

          data = ''.join([elem for elem in data])
          fitnessScore = 0
          for inloop in range(len(target)):
                if (data[inloop] == target[inloop]):
                        fitnessScore = fitnessScore + 1
          return fitnessScore



def maxProb(probabilityDist):
        probabilityList = [f for f in set(probabilityDist)]
        return (probabilityList[len(probabilityList)-2])



def viewElement(data):
          data = ''.join([elem for elem in data])
          return data        

        

class NQueens_puzzle:
    #This is the class to generate all the valid solutions for the N Queens puzzle
    def __init__(self,size):
        # Chess Board Size and valid solutions count
        self.size = size
        self.total_solutions_count = 0


    def solve_nqueens_puzzle(self):
        #Solve the N Queens puzzle and return the number of solutions.

        final_list=[]
        positions = [-1] * self.size
        self.place_queen(positions, 0,final_list)
        return final_list


    def place_queen(self, positions, current_row,final_list):
        
        # This class method places a queen on the row being checked(current_row) by ignoring the places under attack
        # due to already filled rows and selecting the first safe position found in the column for the current row.
        # If a valid place is found, then the function calls itself trying to place a queen
        # on the next row until all N queens are placed on the NxN board.
        
        if current_row == self.size:
            
            self.prep_final_list(positions,final_list)
            self.total_solutions_count += 1
            #print(f"Solution Count :: {self.total_solutions_count}")
            #print(f"Solution ::  {positions}")
        else:
            # Call the check_pos class method to retrieve the safe column position for the current row
            # which is not under attack from already filled positions.
            # Place the Queen in the safe column and iterate again for the next row Queen position.
            for column in range(self.size):
                if self.check_pos(positions, current_row, column):
                    positions[current_row] = column
                    self.place_queen(positions, current_row + 1,final_list)
        


    def check_pos(self, positions, filled_rows, column):
        # Check and return False if the current column is under attack from any of filled Queens.
        # Return True if column is not under attack.
        for i in range(filled_rows):
            if positions[i] == column or \
                positions[i] - i == column - filled_rows or \
                positions[i] + i == column + filled_rows:

                return False
        return True

    def prep_final_list(self, positions,final_list):
        # Prepare the final list by appending each solution set
        
        current_list=[]
        for row in range(self.size):
            line = ""
            for column in range(self.size):
                if positions[row] == column:
                    current_list.append(str(column))
        final_list.append(current_list)



if __name__ == "__main__":

    main()
# Out:
# Thread 05726314 Generation 0 |Offspring1 :05446174|FS of Offspring1: 4|Offspring2 :71150316|FS of Offspring2 :2
# Thread 06357142 Generation 0 |Offspring1 :75733122|FS of Offspring1: 2|Offspring2 :56577142|FS of Offspring2 :5
#
# Thread 04752613 Generation 0 |Offspring1 :06116613|FS of Offspring1: 4|Offspring2 :20672425|FS of Offspring2 :1
#
#
# Thread 05726314 Generation 1 |Offspring1 :05446312|FS of Offspring1: 5|Offspring2 :05446144|FS of Offspring2 :4
#
# Thread 04752613 Generation 1 |Offspring1 :06112032|FS of Offspring1: 2|Offspring2 :64006113|FS of Offspring2 :3
#
# Thread 05726314 Generation 2 |Offspring1 :05476144|FS of Offspring1: 4|Offspring2 :05446352|FS of Offspring2 :4
#
# Thread 06357142 Generation 1 |Offspring1 :56570142|FS of Offspring1: 4|Offspring2 :76737112|FS of Offspring2 :4
#
# Thread 05726314 Generation 3 |Offspring1 :05446052|FS of Offspring1: 3|Offspring2 :05440312|FS of Offspring2 :4
#
# Thread 04752613 Generation 2 |Offspring1 :06116153|FS of Offspring1: 2|Offspring2 :64006613|FS of Offspring2 :4
#
# Thread 13572064 Generation 0 |Offspring1 :73777504|FS of Offspring1: 3|Offspring2 :13177063|FS of Offspring2 :5
# Thread 05726314 Generation 4 |Offspring1 :05445312|FS of Offspring1: 4|Offspring2 :05456312|FS of Offspring2 :5
#
# Thread 06471352 Generation 0 |Offspring1 :36441413|FS of Offspring1: 3|Offspring2 :06122454|FS of Offspring2 :3
#
# Thread 06357142 Generation 2 |Offspring1 :50577112|FS of Offspring1: 3|Offspring2 :76737342|FS of Offspring2 :4
#
# Thread 14602753 Generation 0 |Offspring1 :17703456|FS of Offspring1: 3|Offspring2 :11006753|FS of Offspring2 :5
#
# Thread 04752613 Generation 3 |Offspring1 :64306613|FS of Offspring1: 4|Offspring2 :06516613|FS of Offspring2 :4
# Thread 14630752 Generation 0 |Offspring1 :11230352|FS of Offspring1: 5|Offspring2 :33060332|FS of Offspring2 :2
# Thread 13572064 Generation 1 |Offspring1 :13177763|FS of Offspring1: 4|Offspring2 :23777063|FS of Offspring2 :4
#
#
#
# Thread 15720364 Generation 0 |Offspring1 :54325364|FS of Offspring1: 4|Offspring2 :14230374|FS of Offspring2 :4
#
#
# Thread 14602753 Generation 1 |Offspring1 :12003456|FS of Offspring1: 3|Offspring2 :11616753|FS of Offspring2 :5
# Thread 13572064 Generation 2 |Offspring1 :13177063|FS of Offspring1: 5|Offspring2 :23777033|FS of Offspring2 :3
#
# Thread 04752613 Generation 4 |Offspring1 :06516610|FS of Offspring1: 3|Offspring2 :00116613|FS of Offspring2 :4
#
# Thread 06357142 Generation 3 |Offspring1 :56517342|FS of Offspring1: 4|Offspring2 :76237142|FS of Offspring2 :5
#
# Thread 15720364 Generation 1 |Offspring1 :14320374|FS of Offspring1: 5|Offspring2 :10230374|FS of Offspring2 :4
#
# Thread 04752613 Generation 5 |Offspring1 :00116113|FS of Offspring1: 3|Offspring2 :06510613|FS of Offspring2 :4
#
#
# Thread 15720364 Generation 2 |Offspring1 :64320374|FS of Offspring1: 4|Offspring2 :16320374|FS of Offspring2 :5
#
# Thread 06471352 Generation 1 |Offspring1 :06431416|FS of Offspring1: 4|Offspring2 :06173212|FS of Offspring2 :4
#
# Thread 14602753 Generation 2 |Offspring1 :11616753|FS of Offspring1: 5|Offspring2 :71006753|FS of Offspring2 :4
# Thread 14630752 Generation 1 |Offspring1 :11230330|FS of Offspring1: 3|Offspring2 :11230353|FS of Offspring2 :4
#
# Thread 05726314 Generation 5 |Offspring1 :35456312|FS of Offspring1: 4|Offspring2 :05447312|FS of Offspring2 :4
#
# Thread 04752613 Generation 6 |Offspring1 :56516613|FS of Offspring1: 3|Offspring2 :06115613|FS of Offspring2 :4
#
#
# Thread 15720364 Generation 3 |Offspring1 :36320374|FS of Offspring1: 4|Offspring2 :14320375|FS of Offspring2 :4
#
# Thread 04752613 Generation 7 |Offspring1 :06110673|FS of Offspring1: 3|Offspring2 :06515613|FS of Offspring2 :4
#
# Thread 06471352 Generation 2 |Offspring1 :06171443|FS of Offspring1: 4|Offspring2 :06173215|FS of Offspring2 :3
# Thread 13572064 Generation 3 |Offspring1 :13177062|FS of Offspring1: 5|Offspring2 :10177063|FS of Offspring2 :4
#
#
# Thread 15720364 Generation 4 |Offspring1 :10320374|FS of Offspring1: 5|Offspring2 :16321374|FS of Offspring2 :4
#
# Thread 06357142 Generation 4 |Offspring1 :76234142|FS of Offspring1: 4|Offspring2 :56577102|FS of Offspring2 :4
#
# Thread 14630752 Generation 2 |Offspring1 :11230653|FS of Offspring1: 4|Offspring2 :11236352|FS of Offspring2 :4
#
# Thread 04752613 Generation 8 |Offspring1 :06515613|FS of Offspring1: 4|Offspring2 :16115613|FS of Offspring2 :3
#
# Thread 14630752 Generation 3 |Offspring1 :11236352|FS of Offspring1: 4|Offspring2 :11230252|FS of Offspring2 :5
#
# Thread 20647135 Generation 0 |Offspring1 :20627735|FS of Offspring1: 6|Offspring2 :56347250|FS of Offspring2 :2
# Thread 06357142 Generation 5 |Offspring1 :66237142|FS of Offspring1: 5|Offspring2 :56577242|FS of Offspring2 :4
#
#
# Thread 16470352 Generation 0 |Offspring1 :13476336|FS of Offspring1: 4|Offspring2 :12433354|FS of Offspring2 :4
#
# Thread 16257403 Generation 0 |Offspring1 :14270773|FS of Offspring1: 3|Offspring2 :14450607|FS of Offspring2 :3
# Thread 15063724 Generation 0 |Offspring1 :75763410|FS of Offspring1: 3|Offspring2 :15153227|FS of Offspring2 :4
#
# Thread 17502463 Generation 0 |Offspring1 :52502664|FS of Offspring1: 4|Offspring2 :41071413|FS of Offspring2 :2
# Thread 20647135 Generation 1 |Offspring1 :25627735|FS of Offspring1: 5|Offspring2 :56347735|FS of Offspring2 :4
#
# Thread 13572064 Generation 4 |Offspring1 :17177063|FS of Offspring1: 4|Offspring2 :13137062|FS of Offspring2 :4
#
# Thread 06357142 Generation 6 |Offspring1 :76227142|FS of Offspring1: 5|Offspring2 :06577142|FS of Offspring2 :6
#
# Thread 04752613 Generation 9 |Offspring1 :64005612|FS of Offspring1: 3|Offspring2 :06316613|FS of Offspring2 :4
#
#
# Thread 14630752 Generation 4 |Offspring1 :16230352|FS of Offspring1: 5|Offspring2 :11232252|FS of Offspring2 :4
#
# Thread 15720364 Generation 5 |Offspring1 :24320374|FS of Offspring1: 4|Offspring2 :30320374|FS of Offspring2 :4
#
# Thread 13572064 Generation 5 |Offspring1 :13174063|FS of Offspring1: 5|Offspring2 :13177062|FS of Offspring2 :5
#
#
# Thread 13572064 Generation 6 |Offspring1 :13177063|FS of Offspring1: 5|Offspring2 :13177562|FS of Offspring2 :4
#
# Thread 05726314 Generation 6 |Offspring1 :05456313|FS of Offspring1: 5|Offspring2 :05446342|FS of Offspring2 :4
#
# Thread 14602753 Generation 3 |Offspring1 :16006753|FS of Offspring1: 5|Offspring2 :11616753|FS of Offspring2 :5
#
# Thread 06471352 Generation 3 |Offspring1 :36471436|FS of Offspring1: 4|Offspring2 :46432454|FS of Offspring2 :3
#
# Thread 15720364 Generation 6 |Offspring1 :14320373|FS of Offspring1: 4|Offspring2 :10320370|FS of Offspring2 :4
#
# Thread 05726314 Generation 7 |Offspring1 :15456312|FS of Offspring1: 4|Offspring2 :05466312|FS of Offspring2 :5
#
# Thread 20647135 Generation 2 |Offspring1 :20627731|FS of Offspring1: 5|Offspring2 :25627705|FS of Offspring2 :4
#
# Thread 14630752 Generation 5 |Offspring1 :11236352|FS of Offspring1: 4|Offspring2 :16230372|FS of Offspring2 :4
#
# Thread 13572064 Generation 7 |Offspring1 :14177063|FS of Offspring1: 4|Offspring2 :13177062|FS of Offspring2 :5
#
# Thread 16257403 Generation 1 |Offspring1 :16272607|FS of Offspring1: 4|Offspring2 :16450607|FS of Offspring2 :4
# Thread 15063724 Generation 1 |Offspring1 :65153410|FS of Offspring1: 2|Offspring2 :15163223|FS of Offspring2 :5
#
# Thread 15720364 Generation 7 |Offspring1 :14420374|FS of Offspring1: 5|Offspring2 :10320334|FS of Offspring2 :5
#
# Thread 15063724 Generation 2 |Offspring1 :15063227|FS of Offspring1: 6|Offspring2 :12153223|FS of Offspring2 :3
#
#
# Thread 14602753 Generation 4 |Offspring1 :11716753|FS of Offspring1: 4|Offspring2 :16005753|FS of Offspring2 :5
#
# Thread 14602753 Generation 5 |Offspring1 :16006753|FS of Offspring1: 5|Offspring2 :11715753|FS of Offspring2 :4
#
# Thread 04752613 Generation 10 |Offspring1 :06355613|FS of Offspring1: 5|Offspring2 :06516653|FS of Offspring2 :3
#
# Thread 17502463 Generation 1 |Offspring1 :43572664|FS of Offspring1: 3|Offspring2 :54502663|FS of Offspring2 :5
# Thread 13572064 Generation 8 |Offspring1 :13177043|FS of Offspring1: 4|Offspring2 :13177065|FS of Offspring2 :5
#
# Thread 16470352 Generation 1 |Offspring1 :13676336|FS of Offspring1: 3|Offspring2 :13473653|FS of Offspring2 :4
#
# Thread 14630752 Generation 6 |Offspring1 :11330352|FS of Offspring1: 5|Offspring2 :16270352|FS of Offspring2 :4
#
# Thread 20647135 Generation 3 |Offspring1 :20627431|FS of Offspring1: 5|Offspring2 :20677735|FS of Offspring2 :6
#
# Thread 15720364 Generation 8 |Offspring1 :10020374|FS of Offspring1: 5|Offspring2 :10320334|FS of Offspring2 :5
#
# Thread 15720364 Generation 9 |Offspring1 :10520374|FS of Offspring1: 5|Offspring2 :34420334|FS of Offspring2 :4
#
# Thread 06357142 Generation 7 |Offspring1 :06547142|FS of Offspring1: 6|Offspring2 :76207142|FS of Offspring2 :5
#
#
# Thread 24170635 Generation 0 |Offspring1 :17145633|FS of Offspring1: 3|Offspring2 :14170235|FS of Offspring2 :6
# Thread 24175360 Generation 0 |Offspring1 :27016363|FS of Offspring1: 3|Offspring2 :34230160|FS of Offspring2 :3
#
# Thread 06471352 Generation 4 |Offspring1 :36416212|FS of Offspring1: 3|Offspring2 :06401436|FS of Offspring2 :4
# Thread 20647135 Generation 4 |Offspring1 :20627735|FS of Offspring1: 6|Offspring2 :20727735|FS of Offspring2 :5
#
# Thread 15720364 Generation 10 |Offspring1 :14325374|FS of Offspring1: 4|Offspring2 :10520374|FS of Offspring2 :5
# Thread 14630752 Generation 7 |Offspring1 :11333352|FS of Offspring1: 4|Offspring2 :11230355|FS of Offspring2 :4
#
# Thread 15063724 Generation 3 |Offspring1 :15003223|FS of Offspring1: 5|Offspring2 :15163427|FS of Offspring2 :5
#
#
# Thread 24730615 Generation 0 |Offspring1 :24332046|FS of Offspring1: 3|Offspring2 :25731565|FS of Offspring2 :4
#
# Thread 20647135 Generation 5 |Offspring1 :20627737|FS of Offspring1: 5|Offspring2 :25627735|FS of Offspring2 :5
#
# Thread 06471352 Generation 5 |Offspring1 :06106212|FS of Offspring1: 3|Offspring2 :06431446|FS of Offspring2 :4
#
# Thread 24603175 Generation 0 |Offspring1 :71601373|FS of Offspring1: 3|Offspring2 :27673371|FS of Offspring2 :4
# Thread 24175360 Generation 1 |Offspring1 :34134160|FS of Offspring1: 4|Offspring2 :24016360|FS of Offspring2 :5
#
#
# Thread 13572064 Generation 9 |Offspring1 :03177063|FS of Offspring1: 4|Offspring2 :13147065|FS of Offspring2 :4
#
# Thread 24730615 Generation 1 |Offspring1 :23731465|FS of Offspring1: 4|Offspring2 :25331565|FS of Offspring2 :3
#
# Thread 15720364 Generation 11 |Offspring1 :10520372|FS of Offspring1: 4|Offspring2 :14370374|FS of Offspring2 :4
#
#
# Thread 14602753 Generation 6 |Offspring1 :17005753|FS of Offspring1: 5|Offspring2 :16006453|FS of Offspring2 :4
#
# Thread 16257403 Generation 2 |Offspring1 :16752607|FS of Offspring1: 4|Offspring2 :16770607|FS of Offspring2 :3
#
# Thread 20647135 Generation 6 |Offspring1 :20627730|FS of Offspring1: 5|Offspring2 :20627735|FS of Offspring2 :6
#
# Thread 15063724 Generation 4 |Offspring1 :15063477|FS of Offspring1: 5|Offspring2 :15163207|FS of Offspring2 :4
#
# Thread 06357142 Generation 8 |Offspring1 :06547142|FS of Offspring1: 6|Offspring2 :06477142|FS of Offspring2 :6
#
# Thread 16470352 Generation 2 |Offspring1 :13473623|FS of Offspring1: 3|Offspring2 :13433353|FS of Offspring2 :4
#
# Thread 15720364 Generation 12 |Offspring1 :36320334|FS of Offspring1: 4|Offspring2 :10420374|FS of Offspring2 :5
#
# Thread 24730615 Generation 2 |Offspring1 :24331765|FS of Offspring1: 4|Offspring2 :23731465|FS of Offspring2 :4
#
# Thread 24175360 Generation 2 |Offspring1 :24017363|FS of Offspring1: 4|Offspring2 :34736360|FS of Offspring2 :4
#
# Thread 04752613 Generation 11 |Offspring1 :06355663|FS of Offspring1: 4|Offspring2 :06515614|FS of Offspring2 :3
#
# Thread 17502463 Generation 2 |Offspring1 :54501473|FS of Offspring1: 4|Offspring2 :57502663|FS of Offspring2 :6
#
# Thread 13572064 Generation 10 |Offspring1 :03177062|FS of Offspring1: 4|Offspring2 :12177062|FS of Offspring2 :4
#
# Thread 14602753 Generation 7 |Offspring1 :11616053|FS of Offspring1: 4|Offspring2 :06006753|FS of Offspring2 :4
#
# Thread 17502463 Generation 3 |Offspring1 :57502263|FS of Offspring1: 6|Offspring2 :54502663|FS of Offspring2 :5
#
# Thread 14630752 Generation 8 |Offspring1 :11730352|FS of Offspring1: 5|Offspring2 :11330342|FS of Offspring2 :4
#
# Thread 24175360 Generation 3 |Offspring1 :24016360|FS of Offspring1: 5|Offspring2 :34731360|FS of Offspring2 :4
#
# Thread 24730615 Generation 3 |Offspring1 :03731765|FS of Offspring1: 3|Offspring2 :24311465|FS of Offspring2 :3
# Thread 25147063 Generation 0 |Offspring1 :37147161|FS of Offspring1: 4|Offspring2 :55044034|FS of Offspring2 :3
#
# Thread 15720364 Generation 13 |Offspring1 :10400374|FS of Offspring1: 4|Offspring2 :10540374|FS of Offspring2 :4
#
# Thread 05726314 Generation 8 |Offspring1 :05466312|FS of Offspring1: 5|Offspring2 :02446312|FS of Offspring2 :4
#
# Thread 24170635 Generation 1 |Offspring1 :14170535|FS of Offspring1: 6|Offspring2 :17140205|FS of Offspring2 :3
#
# Thread 16470352 Generation 3 |Offspring1 :10473353|FS of Offspring1: 5|Offspring2 :13433353|FS of Offspring2 :4
#
# Thread 24730615 Generation 4 |Offspring1 :24331465|FS of Offspring1: 4|Offspring2 :03731465|FS of Offspring2 :3
# Thread 25147063 Generation 1 |Offspring1 :20147161|FS of Offspring1: 5|Offspring2 :37144011|FS of Offspring2 :3
# Thread 15720364 Generation 14 |Offspring1 :10520344|FS of Offspring1: 5|Offspring2 :14340374|FS of Offspring2 :4
# Thread 24175360 Generation 4 |Offspring1 :24016360|FS of Offspring1: 5|Offspring2 :24216360|FS of Offspring2 :5
#
# Thread 17502463 Generation 4 |Offspring1 :57542663|FS of Offspring1: 5|Offspring2 :57502263|FS of Offspring2 :6
# Thread 15063724 Generation 5 |Offspring1 :15763223|FS of Offspring1: 5|Offspring2 :15663227|FS of Offspring2 :5
#
# Thread 25164073 Generation 0 |Offspring1 :16164002|FS of Offspring1: 4|Offspring2 :42064013|FS of Offspring2 :4
#
#
# Thread 05726314 Generation 9 |Offspring1 :05456312|FS of Offspring1: 5|Offspring2 :05466322|FS of Offspring2 :4
# Thread 20647135 Generation 7 |Offspring1 :21627735|FS of Offspring1: 5|Offspring2 :20627725|FS of Offspring2 :5
#
#
#
# Thread 24603175 Generation 1 |Offspring1 :27673775|FS of Offspring1: 5|Offspring2 :71611371|FS of Offspring2 :2
#
# Thread 25164073 Generation 1 |Offspring1 :42062063|FS of Offspring1: 3|Offspring2 :25744014|FS of Offspring2 :4
#
# Thread 16257403 Generation 3 |Offspring1 :36272607|FS of Offspring1: 3|Offspring2 :14750607|FS of Offspring2 :3
#
# Thread 14602753 Generation 8 |Offspring1 :11616754|FS of Offspring1: 4|Offspring2 :11616753|FS of Offspring2 :5
#
# Thread 04752613 Generation 12 |Offspring1 :06356613|FS of Offspring1: 5|Offspring2 :50115613|FS of Offspring2 :3
#
# Thread 06357142 Generation 9 |Offspring1 :06477142|FS of Offspring1: 6|Offspring2 :06547147|FS of Offspring2 :5
#
# Thread 16257403 Generation 4 |Offspring1 :16270207|FS of Offspring1: 4|Offspring2 :66272607|FS of Offspring2 :3
#
#
# Thread 25317460 Generation 0 |Offspring1 :21627071|FS of Offspring1: 2|Offspring2 :25614520|FS of Offspring2 :4
#
# Thread 25160374 Generation 0 |Offspring1 :00170224|FS of Offspring1: 3|Offspring2 :25200344|FS of Offspring2 :5
# Thread 06471352 Generation 6 |Offspring1 :06446212|FS of Offspring1: 4|Offspring2 :06231446|FS of Offspring2 :3
#
#
# Thread 25307461 Generation 0 |Offspring1 :75336053|FS of Offspring1: 2|Offspring2 :25367162|FS of Offspring2 :5
# Thread 20647135 Generation 8 |Offspring1 :20227735|FS of Offspring1: 5|Offspring2 :20727735|FS of Offspring2 :5
#
# Thread 25164073 Generation 2 |Offspring1 :25743002|FS of Offspring1: 3|Offspring2 :16164004|FS of Offspring2 :4
#
# Thread 14630752 Generation 9 |Offspring1 :11234352|FS of Offspring1: 4|Offspring2 :13230252|FS of Offspring2 :5
#
# Thread 24170635 Generation 2 |Offspring1 :14170135|FS of Offspring1: 6|Offspring2 :14170530|FS of Offspring2 :5
#
# Thread 13572064 Generation 11 |Offspring1 :13177066|FS of Offspring1: 5|Offspring2 :13177063|FS of Offspring2 :5
#
#
# Thread 15063724 Generation 6 |Offspring1 :11063227|FS of Offspring1: 5|Offspring2 :35663227|FS of Offspring2 :4
#
# Thread 25147063 Generation 2 |Offspring1 :20107161|FS of Offspring1: 4|Offspring2 :37347161|FS of Offspring2 :3
#
#
# Thread 25317460 Generation 1 |Offspring1 :27614420|FS of Offspring1: 4|Offspring2 :21324570|FS of Offspring2 :3
# Thread 25164073 Generation 3 |Offspring1 :06164013|FS of Offspring1: 5|Offspring2 :16124074|FS of Offspring2 :4
#
# Thread 06357142 Generation 10 |Offspring1 :06527142|FS of Offspring1: 6|Offspring2 :06477142|FS of Offspring2 :6
#
#
# Thread 16257403 Generation 5 |Offspring1 :16050207|FS of Offspring1: 4|Offspring2 :16250607|FS of Offspring2 :5
#
# Thread 13572064 Generation 12 |Offspring1 :03177066|FS of Offspring1: 4|Offspring2 :13177063|FS of Offspring2 :5
#
# Thread 14630752 Generation 10 |Offspring1 :53230352|FS of Offspring1: 4|Offspring2 :11236252|FS of Offspring2 :4
#
# Thread 24175360 Generation 5 |Offspring1 :24266360|FS of Offspring1: 5|Offspring2 :24016360|FS of Offspring2 :5
#
# Thread 25307461 Generation 1 |Offspring1 :65367562|FS of Offspring1: 4|Offspring2 :75377462|FS of Offspring2 :5
#
# Thread 25704613 Generation 0 |Offspring1 :17106473|FS of Offspring1: 2|Offspring2 :76744211|FS of Offspring2 :3
#
#
# Thread 24730615 Generation 5 |Offspring1 :04331765|FS of Offspring1: 3|Offspring2 :04331465|FS of Offspring2 :3
#
# Thread 13572064 Generation 13 |Offspring1 :13177063|FS of Offspring1: 5|Offspring2 :13177023|FS of Offspring2 :4
#
# Thread 14602753 Generation 9 |Offspring1 :11615773|FS of Offspring1: 4|Offspring2 :17006755|FS of Offspring2 :4
# Thread 06471352 Generation 7 |Offspring1 :36473454|FS of Offspring1: 4|Offspring2 :36470436|FS of Offspring2 :3
# Thread 17502463 Generation 5 |Offspring1 :50502663|FS of Offspring1: 5|Offspring2 :57502213|FS of Offspring2 :5
#
#
# Thread 25147063 Generation 3 |Offspring1 :24147161|FS of Offspring1: 5|Offspring2 :20105161|FS of Offspring2 :3
#
#
# Thread 15063724 Generation 7 |Offspring1 :15063427|FS of Offspring1: 6|Offspring2 :10063227|FS of Offspring2 :5
#
# Thread 24175360 Generation 6 |Offspring1 :24016560|FS of Offspring1: 4|Offspring2 :24166360|FS of Offspring2 :6
#
# Thread 16257403 Generation 6 |Offspring1 :16252605|FS of Offspring1: 5|Offspring2 :16750607|FS of Offspring2 :4
# Thread 15720364 Generation 15 |Offspring1 :14320377|FS of Offspring1: 4|Offspring2 :10040374|FS of Offspring2 :4
#
# Thread 24603175 Generation 2 |Offspring1 :27613371|FS of Offspring1: 4|Offspring2 :27673775|FS of Offspring2 :5
# Thread 24170635 Generation 3 |Offspring1 :14170533|FS of Offspring1: 5|Offspring2 :14170635|FS of Offspring2 :7
#
# Thread 25164073 Generation 4 |Offspring1 :06164064|FS of Offspring1: 4|Offspring2 :16123013|FS of Offspring2 :3
#
# Thread 25704613 Generation 1 |Offspring1 :76734354|FS of Offspring1: 2|Offspring2 :75774211|FS of Offspring2 :4
#
# Thread 25317460 Generation 2 |Offspring1 :25324420|FS of Offspring1: 5|Offspring2 :27714420|FS of Offspring2 :4
#
# Thread 06357142 Generation 11 |Offspring1 :06471142|FS of Offspring1: 5|Offspring2 :06517142|FS of Offspring2 :6
#
# Thread 14602753 Generation 10 |Offspring1 :11616753|FS of Offspring1: 5|Offspring2 :16006756|FS of Offspring2 :4
#
# Thread 14630752 Generation 11 |Offspring1 :11230252|FS of Offspring1: 5|Offspring2 :11230352|FS of Offspring2 :5
# Thread 26174035 Generation 0 |Offspring1 :41370072|FS of Offspring1: 2|Offspring2 :16272025|FS of Offspring2 :4
# Thread 16470352 Generation 4 |Offspring1 :13473351|FS of Offspring1: 5|Offspring2 :10423353|FS of Offspring2 :4
#
#
# Thread 05726314 Generation 10 |Offspring1 :05446313|FS of Offspring1: 5|Offspring2 :05456312|FS of Offspring2 :5
#
# Thread 24175360 Generation 7 |Offspring1 :24116360|FS of Offspring1: 6|Offspring2 :20016360|FS of Offspring2 :4
#
# Thread 25164073 Generation 5 |Offspring1 :06161013|FS of Offspring1: 4|Offspring2 :16024013|FS of Offspring2 :3
#
#
# Thread 04752613 Generation 13 |Offspring1 :06355611|FS of Offspring1: 4|Offspring2 :06356313|FS of Offspring2 :4
#
# Thread 25713064 Generation 0 |Offspring1 :27401764|FS of Offspring1: 3|Offspring2 :13753214|FS of Offspring2 :3
# Thread 24603175 Generation 3 |Offspring1 :27673575|FS of Offspring1: 5|Offspring2 :27676775|FS of Offspring2 :4
#
# Thread 25147063 Generation 4 |Offspring1 :23147161|FS of Offspring1: 5|Offspring2 :20141161|FS of Offspring2 :4
#
# Thread 25160374 Generation 1 |Offspring1 :25200214|FS of Offspring1: 4|Offspring2 :07170344|FS of Offspring2 :4
#
# Thread 15063724 Generation 8 |Offspring1 :15063227|FS of Offspring1: 6|Offspring2 :15023427|FS of Offspring2 :5
#
# Thread 25703641 Generation 0 |Offspring1 :75701545|FS of Offspring1: 4|Offspring2 :77231701|FS of Offspring2 :1
# Thread 25307461 Generation 2 |Offspring1 :75377122|FS of Offspring1: 3|Offspring2 :15367462|FS of Offspring2 :5
# Thread 25704613 Generation 2 |Offspring1 :75774354|FS of Offspring1: 3|Offspring2 :65744211|FS of Offspring2 :4
#
# Thread 24730615 Generation 6 |Offspring1 :04331465|FS of Offspring1: 3|Offspring2 :24334765|FS of Offspring2 :4
# Thread 15063724 Generation 9 |Offspring1 :55063227|FS of Offspring1: 5|Offspring2 :15066227|FS of Offspring2 :5
#
# Thread 26174035 Generation 1 |Offspring1 :16274072|FS of Offspring1: 4|Offspring2 :16272055|FS of Offspring2 :4
#
#
#
# Thread 24603175 Generation 4 |Offspring1 :27603775|FS of Offspring1: 6|Offspring2 :27673075|FS of Offspring2 :5
#
#
# Thread 20647135 Generation 9 |Offspring1 :20647735|FS of Offspring1: 7|Offspring2 :20627735|FS of Offspring2 :6
#
# Thread 25147063 Generation 5 |Offspring1 :23147161|FS of Offspring1: 5|Offspring2 :26147161|FS of Offspring2 :5
#
# Thread 13572064 Generation 14 |Offspring1 :13174066|FS of Offspring1: 5|Offspring2 :13175063|FS of Offspring2 :5
#
# Thread 17502463 Generation 6 |Offspring1 :57502763|FS of Offspring1: 6|Offspring2 :57504663|FS of Offspring2 :5
#
# Thread 06471352 Generation 8 |Offspring1 :36476212|FS of Offspring1: 4|Offspring2 :06172454|FS of Offspring2 :4
#
# Thread 16257403 Generation 7 |Offspring1 :16250601|FS of Offspring1: 5|Offspring2 :16252606|FS of Offspring2 :5
#
#
# Thread 06357142 Generation 12 |Offspring1 :06517042|FS of Offspring1: 5|Offspring2 :06447142|FS of Offspring2 :6
#
# Thread 25160374 Generation 2 |Offspring1 :25200346|FS of Offspring1: 4|Offspring2 :02170344|FS of Offspring2 :4
#
# Thread 14630752 Generation 12 |Offspring1 :11230252|FS of Offspring1: 5|Offspring2 :13210352|FS of Offspring2 :4
#
# Thread 25713064 Generation 1 |Offspring1 :13153345|FS of Offspring1: 1|Offspring2 :35713214|FS of Offspring2 :5
#
# Thread 24170635 Generation 4 |Offspring1 :14170133|FS of Offspring1: 5|Offspring2 :14170735|FS of Offspring2 :6
# Thread 04752613 Generation 14 |Offspring1 :06355213|FS of Offspring1: 4|Offspring2 :00356613|FS of Offspring2 :5
#
# Thread 05726314 Generation 11 |Offspring1 :55456313|FS of Offspring1: 4|Offspring2 :15446312|FS of Offspring2 :4
# Thread 15720364 Generation 16 |Offspring1 :10520374|FS of Offspring1: 5|Offspring2 :14220374|FS of Offspring2 :5
# Thread 26174035 Generation 2 |Offspring1 :16274002|FS of Offspring1: 4|Offspring2 :16272025|FS of Offspring2 :4
#
#
# Thread 17502463 Generation 7 |Offspring1 :57572663|FS of Offspring1: 5|Offspring2 :57542763|FS of Offspring2 :5
#
# Thread 14602753 Generation 11 |Offspring1 :06005753|FS of Offspring1: 4|Offspring2 :16076753|FS of Offspring2 :4
#
#
# Thread 20647135 Generation 10 |Offspring1 :20647730|FS of Offspring1: 6|Offspring2 :20627135|FS of Offspring2 :7
#
# Thread 25164073 Generation 6 |Offspring1 :06164202|FS of Offspring1: 3|Offspring2 :45062013|FS of Offspring2 :4
#
# Thread 25713064 Generation 2 |Offspring1 :31710464|FS of Offspring1: 4|Offspring2 :55533215|FS of Offspring2 :2
#
#
# Thread 25704613 Generation 3 |Offspring1 :65704211|FS of Offspring1: 5|Offspring2 :75074211|FS of Offspring2 :3
#
# Thread 15063724 Generation 10 |Offspring1 :12063227|FS of Offspring1: 5|Offspring2 :15063237|FS of Offspring2 :5
#
# Thread 14630752 Generation 13 |Offspring1 :11240352|FS of Offspring1: 4|Offspring2 :11210252|FS of Offspring2 :4
#
# Thread 24730615 Generation 7 |Offspring1 :24334565|FS of Offspring1: 4|Offspring2 :25714765|FS of Offspring2 :3
#
# Thread 25147063 Generation 6 |Offspring1 :26147761|FS of Offspring1: 5|Offspring2 :20147261|FS of Offspring2 :5
#
# Thread 16257403 Generation 8 |Offspring1 :16250601|FS of Offspring1: 5|Offspring2 :11252606|FS of Offspring2 :4
#
# Thread 25307461 Generation 3 |Offspring1 :15767462|FS of Offspring1: 4|Offspring2 :70377462|FS of Offspring2 :4
# Thread 25317460 Generation 3 |Offspring1 :25364420|FS of Offspring1: 5|Offspring2 :27014420|FS of Offspring2 :4
#
# Thread 26174035 Generation 3 |Offspring1 :16274002|FS of Offspring1: 4|Offspring2 :16272021|FS of Offspring2 :3
# Thread 24730615 Generation 8 |Offspring1 :24331563|FS of Offspring1: 3|Offspring2 :25131465|FS of Offspring2 :3
#
#
# Thread 25160374 Generation 3 |Offspring1 :25600344|FS of Offspring1: 5|Offspring2 :02170334|FS of Offspring2 :4
#
# Thread 26175304 Generation 0 |Offspring1 :46655677|FS of Offspring1: 2|Offspring2 :26615022|FS of Offspring2 :3
# Thread 25713064 Generation 3 |Offspring1 :35110464|FS of Offspring1: 4|Offspring2 :31713254|FS of Offspring2 :4
#
#
# Thread 15720364 Generation 17 |Offspring1 :14220373|FS of Offspring1: 4|Offspring2 :10520674|FS of Offspring2 :4
#
# Thread 25703641 Generation 1 |Offspring1 :75701701|FS of Offspring1: 4|Offspring2 :75701575|FS of Offspring2 :3
# Thread 15063724 Generation 11 |Offspring1 :15067227|FS of Offspring1: 5|Offspring2 :15063327|FS of Offspring2 :6
# Thread 25317460 Generation 4 |Offspring1 :20324420|FS of Offspring1: 4|Offspring2 :22364420|FS of Offspring2 :4
#
# Thread 24603175 Generation 5 |Offspring1 :27603055|FS of Offspring1: 5|Offspring2 :27673774|FS of Offspring2 :4
#
# Thread 25147063 Generation 7 |Offspring1 :20157761|FS of Offspring1: 4|Offspring2 :26142261|FS of Offspring2 :4
#
# Thread 24170635 Generation 5 |Offspring1 :14070735|FS of Offspring1: 5|Offspring2 :14170735|FS of Offspring2 :6
#
#
#
# Thread 24730615 Generation 9 |Offspring1 :25731565|FS of Offspring1: 4|Offspring2 :23735016|FS of Offspring2 :4
#
# Thread 25160374 Generation 4 |Offspring1 :25600344|FS of Offspring1: 5|Offspring2 :55200344|FS of Offspring2 :4
#
# Thread 30471625 Generation 0 |Offspring1 :76422555|FS of Offspring1: 2|Offspring2 :35250645|FS of Offspring2 :3
#
# Thread 20647135 Generation 11 |Offspring1 :40627735|FS of Offspring1: 5|Offspring2 :20647134|FS of Offspring2 :7
# Thread 25160374 Generation 5 |Offspring1 :25605344|FS of Offspring1: 4|Offspring2 :35600344|FS of Offspring2 :4
#
# Thread 16470352 Generation 5 |Offspring1 :13573353|FS of Offspring1: 4|Offspring2 :10473351|FS of Offspring2 :5
#
#
# Thread 24175360 Generation 8 |Offspring1 :24116360|FS of Offspring1: 6|Offspring2 :22166360|FS of Offspring2 :5
#
# Thread 27360514 Generation 0 |Offspring1 :32366717|FS of Offspring1: 3|Offspring2 :02360644|FS of Offspring2 :4
# Thread 05726314 Generation 12 |Offspring1 :05452312|FS of Offspring1: 4|Offspring2 :05656312|FS of Offspring2 :5
#
# Thread 26175304 Generation 1 |Offspring1 :46625022|FS of Offspring1: 2|Offspring2 :26611322|FS of Offspring2 :3
#
# Thread 16470352 Generation 6 |Offspring1 :10473321|FS of Offspring1: 4|Offspring2 :33473351|FS of Offspring2 :4
#
# Thread 31625704 Generation 0 |Offspring1 :30725720|FS of Offspring1: 4|Offspring2 :11473504|FS of Offspring2 :3
# Thread 17502463 Generation 8 |Offspring1 :57506263|FS of Offspring1: 5|Offspring2 :57502263|FS of Offspring2 :6
# Thread 25317460 Generation 5 |Offspring1 :24324420|FS of Offspring1: 4|Offspring2 :25364420|FS of Offspring2 :5
#
#
# Thread 14630752 Generation 14 |Offspring1 :11230256|FS of Offspring1: 4|Offspring2 :11230342|FS of Offspring2 :4
#
# Thread 26174035 Generation 4 |Offspring1 :66272025|FS of Offspring1: 4|Offspring2 :16224002|FS of Offspring2 :3
#
#
# Thread 05726314 Generation 13 |Offspring1 :05256312|FS of Offspring1: 5|Offspring2 :05446313|FS of Offspring2 :5
#
# Thread 06471352 Generation 9 |Offspring1 :06174212|FS of Offspring1: 4|Offspring2 :06452454|FS of Offspring2 :4
#
# Thread 14602753 Generation 12 |Offspring1 :11616753|FS of Offspring1: 5|Offspring2 :16000753|FS of Offspring2 :5
# Thread 24175360 Generation 9 |Offspring1 :24136360|FS of Offspring1: 6|Offspring2 :24116364|FS of Offspring2 :5
#
#
# Thread 25307461 Generation 4 |Offspring1 :15367452|FS of Offspring1: 4|Offspring2 :65377462|FS of Offspring2 :5
#
# Thread 30475261 Generation 0 |Offspring1 :31675411|FS of Offspring1: 4|Offspring2 :35377261|FS of Offspring2 :5
# Thread 25713064 Generation 4 |Offspring1 :35743254|FS of Offspring1: 4|Offspring2 :31713210|FS of Offspring2 :3
# Thread 16470352 Generation 7 |Offspring1 :13773351|FS of Offspring1: 4|Offspring2 :17473351|FS of Offspring2 :5
#
#
#
# Thread 25704613 Generation 4 |Offspring1 :65704215|FS of Offspring1: 5|Offspring2 :65744221|FS of Offspring2 :3
#
# Thread 06357142 Generation 13 |Offspring1 :06447146|FS of Offspring1: 5|Offspring2 :06517142|FS of Offspring2 :6
# Thread 20647135 Generation 12 |Offspring1 :20647135|FS of Offspring1: 8|Offspring2 :20627234|FS of Offspring2 :5
#
# Thread 25317460 Generation 6 |Offspring1 :25764420|FS of Offspring1: 4|Offspring2 :25324420|FS of Offspring2 :5
#
# Thread 30471625 Generation 1 |Offspring1 :70421434|FS of Offspring1: 3|Offspring2 :00370675|FS of Offspring2 :4
# Thread 17502463 Generation 9 |Offspring1 :57502663|FS of Offspring1: 6|Offspring2 :54502263|FS of Offspring2 :5
# Thread 13572064 Generation 15 |Offspring1 :13177033|FS of Offspring1: 4|Offspring2 :13175066|FS of Offspring2 :5
#
#
# Thread 24603175 Generation 6 |Offspring1 :27673775|FS of Offspring1: 5|Offspring2 :27673715|FS of Offspring2 :4
#
# Thread 26175304 Generation 2 |Offspring1 :46621322|FS of Offspring1: 2|Offspring2 :26617322|FS of Offspring2 :3
#
# Thread 15063724 Generation 12 |Offspring1 :15062427|FS of Offspring1: 5|Offspring2 :15063323|FS of Offspring2 :6
#
# Thread 24730615 Generation 10 |Offspring1 :23731461|FS of Offspring1: 3|Offspring2 :24335076|FS of Offspring2 :3
#
# Thread 25160374 Generation 6 |Offspring1 :25200344|FS of Offspring1: 5|Offspring2 :25600343|FS of Offspring2 :4
#
# Thread 17502463 Generation 10 |Offspring1 :57102263|FS of Offspring1: 5|Offspring2 :53502663|FS of Offspring2 :5
#
# Thread 26174035 Generation 5 |Offspring1 :66274002|FS of Offspring1: 4|Offspring2 :16272015|FS of Offspring2 :4
#
#
# Thread 30471625 Generation 2 |Offspring1 :04370645|FS of Offspring1: 3|Offspring2 :70420675|FS of Offspring2 :4
#
# Thread 15720364 Generation 18 |Offspring1 :16320174|FS of Offspring1: 4|Offspring2 :14320373|FS of Offspring2 :4
#
#
#
# Thread 25713064 Generation 5 |Offspring1 :34713254|FS of Offspring1: 4|Offspring2 :35243214|FS of Offspring2 :3
#
# Thread 17502463 Generation 11 |Offspring1 :57102763|FS of Offspring1: 5|Offspring2 :57572263|FS of Offspring2 :5
#
# Thread 16257403 Generation 9 |Offspring1 :16250601|FS of Offspring1: 5|Offspring2 :06252605|FS of Offspring2 :4
#
# Thread 04752613 Generation 15 |Offspring1 :00356613|FS of Offspring1: 5|Offspring2 :06356113|FS of Offspring2 :4
#
# Thread 25703641 Generation 2 |Offspring1 :75706545|FS of Offspring1: 4|Offspring2 :75701703|FS of Offspring2 :3
# Thread 31625704 Generation 1 |Offspring1 :31725750|FS of Offspring1: 5|Offspring2 :30723104|FS of Offspring2 :4
#
# Thread 14630752 Generation 15 |Offspring1 :11230355|FS of Offspring1: 4|Offspring2 :16030252|FS of Offspring2 :5
#
# Thread 31475026 Generation 0 |Offspring1 :41175622|FS of Offspring1: 4|Offspring2 :02275037|FS of Offspring2 :3
# Thread 05726314 Generation 14 |Offspring1 :05446310|FS of Offspring1: 5|Offspring2 :05456313|FS of Offspring2 :5
#
# Thread 24603175 Generation 7 |Offspring1 :27603475|FS of Offspring1: 6|Offspring2 :27672775|FS of Offspring2 :4
#
# Thread 25307461 Generation 5 |Offspring1 :65577462|FS of Offspring1: 4|Offspring2 :15317462|FS of Offspring2 :5
#
#
# Thread 20647135 Generation 13 |Offspring1 :25647134|FS of Offspring1: 6|Offspring2 :20647135|FS of Offspring2 :8
#
# Thread 14630752 Generation 16 |Offspring1 :16030212|FS of Offspring1: 4|Offspring2 :13230252|FS of Offspring2 :5
#
#
# Thread 25164073 Generation 7 |Offspring1 :06162010|FS of Offspring1: 3|Offspring2 :45067013|FS of Offspring2 :4
#
#
# Thread 31625704 Generation 2 |Offspring1 :31723434|FS of Offspring1: 4|Offspring2 :21725750|FS of Offspring2 :4
# Thread 24730615 Generation 11 |Offspring1 :24344565|FS of Offspring1: 3|Offspring2 :24334265|FS of Offspring2 :4
#  ######## 20647135 is one of the correct sequence of Queens. It is generated first in generation no :14 ########
